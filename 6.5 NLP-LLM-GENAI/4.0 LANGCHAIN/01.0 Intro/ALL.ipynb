# %%
# %pip install -U langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.4-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\damod\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.52 in c:\users\damod\anaconda3\lib\site-packages (from langchain-google-genai) (0.3.59)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\damod\anaconda3\lib\site-packages (from langchain-google-genai) (2.11.4)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\damod\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.39.0)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\damod\anaconda3\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.29.4)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\damod\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\damod\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\damod\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.71.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\damod\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\damod\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\damod\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\damod\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.23.0)
# Requirement already satisfied: anyio in c:\users\damod\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (4.9.0)
# Requirement already satisfied: certifi in c:\users\damod\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\damod\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.0.2)
# Requirement already satisfied: idna in c:\users\damod\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\damod\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\damod\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\damod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\damod\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\damod\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.52->langchain-google-genai) (1.3.0)
# Downloading langchain_google_genai-2.1.4-py3-none-any.whl (44 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 430.4 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 430.4 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 430.4 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 459.9 kB/s eta 0:00:02
#    ------------------------------ --------- 1.0/1.4 MB 547.3 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 547.3 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 547.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 542.3 kB/s eta 0:00:00
# Using cached google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Installing collected packages: proto-plus, grpcio-status, google-api-core, google-ai-generativelanguage, langchain-google-genai
# Successfully installed google-ai-generativelanguage-0.6.18 google-api-core-2.24.2 grpcio-status-1.71.0 langchain-google-genai-2.1.4 proto-plus-1.26.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
import getpass
import os

# %% [markdown]
# AIzaSyCmfRDfgjWYw5P00rpIzAdoKyMbkVCE9nI

# %%
if os.getenv("GOOGLE_API_KEY") is None:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass(prompt="Enter your Google API Key: ")

# %% [markdown]
# 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

# %%
os.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")
os.environ["LANGSMITH_TRACING"] = "true"

# %%
# !pip install -U langchain langchain-openai
# Out:
# Requirement already satisfied: langchain in c:\users\damod\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: langchain-openai in c:\users\damod\anaconda3\lib\site-packages (0.3.16)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\damod\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\users\damod\anaconda3\lib\site-packages (from langchain-openai) (1.76.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\damod\anaconda3\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\damod\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\damod\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\damod\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\damod\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\damod\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\damod\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\damod\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\damod\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\damod\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\damod\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\damod\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\damod\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\damod\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\damod\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: httpcore==1.* in c:\users\damod\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\damod\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\damod\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: colorama in c:\users\damod\anaconda3\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain-openai) (0.4.6)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model = "gemini-2.0-flash",
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries=2
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant.Translate the following text to French."
    ),(
        "human",
        " I Love programming in Python. "
    )
]

# %%
ai_msg = llm.invoke(messages)

# %%
ai_msg
# Out:
# AIMessage(content="J'adore programmer en Python.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--e2e1bf24-7c27-4ef5-ac61-5f40ccb045d8-0', usage_metadata={'input_tokens': 20, 'output_tokens': 8, 'total_tokens': 28, 'input_token_details': {'cache_read': 0}})

# %%
print(ai_msg.content)
# Out:
# J'adore programmer en Python.

# %% [markdown]
# Chaining
# # Chaining

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system","you are a helpfule assistant that translate {input_language} to {output_language}"
        ),
        (
            "human","{input}"
        )
    ]
)
chain = prompt | llm
chain.invoke({
    "input_language":"English",
    "output_language":"German",
    "input":"I Love Programming"
}).content
# Out:
# 'Ich liebe Programmieren.'

# %% [markdown]
# # Image Input

# %%
import base64
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

message_url = HumanMessage(
    content=[
        {
            "text":"text",
            "text":"Describe the image at Url",
        },{
            "type":"image_url","image_url":"https://picsum.photos/seed/picsum/200/300"
        }
    ]
)

result_url = llm.invoke([message_url])
# Out:
# Unrecognized message part format. Assuming it's a text part.

# %%
result_url.content
# Out:
# "Here's a description of the image:\n\nThe image shows a serene landscape featuring a snow-covered mountain range under a pastel-colored sky. The sky is filled with soft, pink and lavender clouds, suggesting either sunrise or sunset. The mountains are covered in snow, with the peak of one mountain prominently visible on the right side of the frame. The foreground appears to be a snow-covered slope, leading up to the mountains. The overall mood is peaceful and tranquil."

# %%
image_file_path = "./agent vs chain.png"

# %%
with open(image_file_path, "rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

# %%
message_local = HumanMessage(
    content=[
        {
            "type":"text",
            "text":"Describe the local image",
        },{
            "type":"image_url",
            "image_url":f"data:image/png;base64,{encoded_image}"
        }
    ]
)

result_local = llm.invoke([message_local])

# %%
print(result_local.content)
# Out:
# Here's a description of the image you sent:
#
# **Overall Structure:**
#
# The image is a diagram comparing "Chains" and "Agents" within the context of a system, likely related to AI or machine learning. It's visually divided into two main sections, one for each concept. The background is a dark blue.
#
# **Top Section: Chains**
#
# *   **Title:** "Chains" in large, white text.
# *   **Input/Output:** A gray "Input" box on the left leads into a network of green and pink boxes connected by lines. This network eventually leads to a gray "Output" box on the right.
# *   **LLMs:** An orange box labeled "LLMs" (likely referring to Large Language Models) is positioned below the network. Arrows indicate that the LLMs interact with the network.
# *   **Tools:** A collection of icons representing various "Tools" is shown. These tools include icons for audio, images, search, code, and more. The tools are connected to the LLMs.
#
# **Bottom Section: Agents**
#
# *   **Title:** "Agents" in large, white text.
# *   **Input/Output:** A gray "Input" box on the left leads into an orange "LLM" box. The LLM box then connects to a cluster of "Tools" icons, similar to the top section. Finally, the tools connect to a green box, which leads to a gray "Output" box on the right.
# *   **Final Answer:** A text label "Final Answer is Generated" is placed above the output box.
# *   **Loop:** A curved arrow indicates a loop from the "Tools" back to the "LLM," suggesting an iterative process. The text "Loop until Answer is Obtained" is placed near the loop.
#
# **Overall Impression:**
#
# The diagram illustrates the difference between "Chains" and "Agents" in how they process input and generate output. "Chains" seem to involve a predefined network of steps, while "Agents" use an LLM to dynamically select and apply tools in a loop until a satisfactory answer is obtained.
#
# **Additional Elements:**
#
# *   The bottom of the image includes text like "Adapted from..." and a website address, suggesting the diagram is sourced from somewhere.
# *   The LangChain logo is also present.

# %%
import base64
from langchain_core.messages import HumanMessage

audio_file_path = "./audio.mp3"
audio_mime_type = "audio/mpeg"

with open(audio_file_path,'rb') as audio_file:
    encoded_audio = base64.b64encode(audio_file.read()).decode("utf-8")

message = HumanMessage(
    content=[
        {
            "type":"text",
            "text":"Transcribe the audio",
        },{
            "type":"media",
            "data": encoded_audio,
            "mime_type": audio_mime_type,
        },
    ]
)

response = llm.invoke([message])

print(response.content)

# %%
import base64

from IPython.display import Image, display
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="models/gemini-2.0-flash-exp-image-generation")

message = {
    "role":"user",
    "content":[
        {
            "type":"text",
            "text":"Generate an image of a cat"
        }
    ]
}
response = llm.invoke([message],generation_config=dict(response_modalities=["TEXT","IMAGE"]))

image_base64 = response.content[1].get("image_url").get("url").split(",")[-1]
image_data = base64.b64decode(image_base64)
display(Image(data=image_data,width=300))

# %%
next_message = {
    "role": "user",
    "content": [
        {
            "type": "text",
            "text": "Can you take the same image and make the cat black?",
        }
    ]
}

response = llm.invoke(
    [message, response, next_message],
    generation_config=dict(response_modalities=["TEXT", "IMAGE"]),
)

image_base64 = response.content[1].get("image_url").get("url").split(",")[-1]

image_data = base64.b64decode(image_base64)
display(Image(data=image_data, width=300))

# %%
message = {
    "role": "user",
    "content": [
        {
            "type": "text",
            "text": "Can you make this cat bright orange?",
        },
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{image_base64}"},
        },
    ],
}

response = llm.invoke(
    [message],
    generation_config=dict(response_modalities=["TEXT", "IMAGE"]),
)
image_base64 = response.content[1].get("image_url").get("url").split(",")[-1]

image_data = base64.b64decode(image_base64)
display(Image(data=image_data, width=300))
