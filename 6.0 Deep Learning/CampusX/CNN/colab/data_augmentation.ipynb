# %% [markdown]
# <a href="https://colab.research.google.com/github/daemonX10/Data-Science/blob/main/6.0%20Deep%20Learning/Youtube/CNN/colab/data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# untar true will unzip it
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 1s 0us/step

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# import pathlib
# data_dir = pathlib.Path('.')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/17062080069_36ac7907d2_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14408977935_a397e796b8_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/9216321995_83df405ea9.jpg'),
#  PosixPath('datasets/flower_photos/roses/9337528427_3d09b7012b.jpg'),
#  PosixPath('datasets/flower_photos/roses/15602874619_03fd934bed.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))

# %%
image_count
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:4]
# Out:
# [PosixPath('datasets/flower_photos/roses/17062080069_36ac7907d2_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/14408977935_a397e796b8_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/9216321995_83df405ea9.jpg'),
#  PosixPath('datasets/flower_photos/roses/9337528427_3d09b7012b.jpg')]

# %%
from PIL import Image

# %%
str(roses[3])
# Out:
# 'flower_photos\\roses\\10894627425_ec76bbc757_n.jpg'

# %%
# for i in range(1,6):
#     img = Image.open(str(roses[i]))
#     img.show()

# %%
tulips = list(data_dir.glob('tulips/*'))
Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x209>

# %%
flowers_images_dict = {
    'roses' : list(data_dir.glob('roses/*')),
    'daisy' : list(data_dir.glob('daisy/*')),
    'dandelion' : list(data_dir.glob('dandelion/*')),
    'sunflowers' : list(data_dir.glob('sunflowers/*')),
    'tulips' : list(data_dir.glob('tulips/*'))
}

# %%
flowers_labels_dict = {
    'roses' : 0,
    'daisy' : 1,
    'dandelion' : 2,
    'sunflowers' : 3,
    'tulips' : 4
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [WindowsPath('flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'flower_photos\\roses\\10090824183_d02c613f10_m.jpg'

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (238, 320, 3)

# %%
# flowers_images_dict

# %%
cv2.resize(img, (180, 180)).shape
# Out:
# (180, 180, 3)

# %%
flowers_labels_dict
# Out:
# {'roses': 0, 'daisy': 1, 'dandelion': 2, 'sunflowers': 3, 'tulips': 4}

# %%
x , y = [], []
for flower_name , images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img, (180, 180))
        x.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(x)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
num_classes = 5

model = Sequential([
    layers.Conv2D(16,kernel_size=(3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,kernel_size=(3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,kernel_size=(3,3),padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 86/86 [==============================] - 8s 20ms/step - loss: 1.2514 - accuracy: 0.4815
# Epoch 2/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.9728 - accuracy: 0.6195
# Epoch 3/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.8102 - accuracy: 0.6926
# Epoch 4/30
# 86/86 [==============================] - 2s 21ms/step - loss: 0.5801 - accuracy: 0.7845
# Epoch 5/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.3838 - accuracy: 0.8656
# Epoch 6/30
# 86/86 [==============================] - 2s 21ms/step - loss: 0.2363 - accuracy: 0.9190
# Epoch 7/30
# 86/86 [==============================] - 2s 22ms/step - loss: 0.1451 - accuracy: 0.9513
# Epoch 8/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.0950 - accuracy: 0.9717
# Epoch 9/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.0442 - accuracy: 0.9866
# Epoch 10/30
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0218 - accuracy: 0.9949
# Epoch 11/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.0103 - accuracy: 0.9993
# Epoch 12/30
# 86/86 [==============================] - 2s 20ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 13/30
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 14/30
# 86/86 [==============================] - 2s 23ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 15/30
# 86/86 [==============================] - 2s 20ms/step - loss: 7.5151e-04 - accuracy: 1.0000
# Epoch 16/30
# 86/86 [==============================] - 2s 20ms/step - loss: 4.5177e-04 - accuracy: 1.0000
# Epoch 17/30
# 86/86 [==============================] - 2s 20ms/step - loss: 3.2364e-04 - accuracy: 1.0000
# Epoch 18/30
# 86/86 [==============================] - 2s 20ms/step - loss: 2.6311e-04 - accuracy: 1.0000
# Epoch 19/30
# 86/86 [==============================] - 2s 20ms/step - loss: 2.2299e-04 - accuracy: 1.0000
# Epoch 20/30
# 86/86 [==============================] - 2s 21ms/step - loss: 1.8700e-04 - accuracy: 1.0000
# Epoch 21/30
# 86/86 [==============================] - 2s 23ms/step - loss: 1.6270e-04 - accuracy: 1.0000
# Epoch 22/30
# 86/86 [==============================] - 2s 21ms/step - loss: 1.4390e-04 - accuracy: 1.0000
# Epoch 23/30
# 86/86 [==============================] - 2s 20ms/step - loss: 1.2761e-04 - accuracy: 1.0000
# Epoch 24/30
# 86/86 [==============================] - 2s 20ms/step - loss: 1.1275e-04 - accuracy: 1.0000
# Epoch 25/30
# 86/86 [==============================] - 2s 20ms/step - loss: 1.0113e-04 - accuracy: 1.0000
# Epoch 26/30
# 86/86 [==============================] - 2s 20ms/step - loss: 9.0678e-05 - accuracy: 1.0000
# Epoch 27/30
# 86/86 [==============================] - 2s 20ms/step - loss: 8.2031e-05 - accuracy: 1.0000
# Epoch 28/30
# 86/86 [==============================] - 2s 22ms/step - loss: 7.5124e-05 - accuracy: 1.0000
# Epoch 29/30
# 86/86 [==============================] - 2s 23ms/step - loss: 6.8351e-05 - accuracy: 1.0000
# Epoch 30/30
# 86/86 [==============================] - 2s 20ms/step - loss: 6.2623e-05 - accuracy: 1.0000

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
#  6/29 [=====>........................] - ETA: 0s - loss: 3.4021 - accuracy: 0.6302
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 29/29 [==============================] - 1s 21ms/step - loss: 3.5077 - accuracy: 0.6394
# [3.507657289505005, 0.6394335627555847]

# %%
predication = model.predict(X_test_scaled)
# Out:
# 29/29 [==============================] - 0s 10ms/step

# %%
score = tf.nn.softmax(predication[0])

# %%
np.argmax(score)
# Out:
# 4

# %%
y_test[0]
# Out:
# 1

# %%
X[0]
img_height = 180
img_width = 180

# %%
data_augmentation = keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal",input_shape = (img_height,img_width,3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1)
])

# %%
plt.axis('off')
plt.imshow(X[0])

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype('uint8'))

# %%
model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

model.fit(X_train_scaled, y_train, epochs=30, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/30
# 86/86 [==============================] - 7s 48ms/step - loss: 1.4349 - accuracy: 0.3775 - val_loss: 1.1838 - val_accuracy: 0.5076
# Epoch 2/30
# 86/86 [==============================] - 3s 31ms/step - loss: 1.0482 - accuracy: 0.5901 - val_loss: 1.0435 - val_accuracy: 0.5817
# Epoch 3/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.9593 - accuracy: 0.6148 - val_loss: 0.9886 - val_accuracy: 0.6275
# Epoch 4/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.8515 - accuracy: 0.6686 - val_loss: 0.9561 - val_accuracy: 0.6329
# Epoch 5/30
# 86/86 [==============================] - 3s 38ms/step - loss: 0.8350 - accuracy: 0.6781 - val_loss: 0.9682 - val_accuracy: 0.6394
# Epoch 6/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.7892 - accuracy: 0.6915 - val_loss: 0.8594 - val_accuracy: 0.6776
# Epoch 7/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.7419 - accuracy: 0.7257 - val_loss: 0.9113 - val_accuracy: 0.6427
# Epoch 8/30
# 86/86 [==============================] - 3s 36ms/step - loss: 0.7277 - accuracy: 0.7195 - val_loss: 0.8473 - val_accuracy: 0.6808
# Epoch 9/30
# 86/86 [==============================] - 3s 32ms/step - loss: 0.7104 - accuracy: 0.7235 - val_loss: 0.8342 - val_accuracy: 0.6841
# Epoch 10/30
# 86/86 [==============================] - 3s 34ms/step - loss: 0.6555 - accuracy: 0.7449 - val_loss: 0.7704 - val_accuracy: 0.7070
# Epoch 11/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.6403 - accuracy: 0.7515 - val_loss: 0.7707 - val_accuracy: 0.7037
# Epoch 12/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.6001 - accuracy: 0.7762 - val_loss: 0.7493 - val_accuracy: 0.7200
# Epoch 13/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.6068 - accuracy: 0.7696 - val_loss: 0.7875 - val_accuracy: 0.7092
# Epoch 14/30
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5766 - accuracy: 0.7831 - val_loss: 0.7663 - val_accuracy: 0.6950
# Epoch 15/30
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5240 - accuracy: 0.8045 - val_loss: 0.8088 - val_accuracy: 0.7059
# Epoch 16/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.5125 - accuracy: 0.8121 - val_loss: 0.7442 - val_accuracy: 0.7190
# Epoch 17/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.4904 - accuracy: 0.8041 - val_loss: 0.7587 - val_accuracy: 0.7168
# Epoch 18/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.4678 - accuracy: 0.8223 - val_loss: 0.7684 - val_accuracy: 0.7157
# Epoch 19/30
# 86/86 [==============================] - 3s 37ms/step - loss: 0.4634 - accuracy: 0.8267 - val_loss: 0.7168 - val_accuracy: 0.7375
# Epoch 20/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.4538 - accuracy: 0.8343 - val_loss: 0.8104 - val_accuracy: 0.7233
# Epoch 21/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.4310 - accuracy: 0.8441 - val_loss: 0.7315 - val_accuracy: 0.7429
# Epoch 22/30
# 86/86 [==============================] - 3s 32ms/step - loss: 0.4211 - accuracy: 0.8394 - val_loss: 0.7065 - val_accuracy: 0.7495
# Epoch 23/30
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4023 - accuracy: 0.8477 - val_loss: 0.7409 - val_accuracy: 0.7397
# Epoch 24/30
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3809 - accuracy: 0.8586 - val_loss: 0.7344 - val_accuracy: 0.7484
# Epoch 25/30
# 86/86 [==============================] - 3s 31ms/step - loss: 0.3189 - accuracy: 0.8837 - val_loss: 0.8387 - val_accuracy: 0.7418
# Epoch 26/30
# 86/86 [==============================] - 3s 32ms/step - loss: 0.3779 - accuracy: 0.8637 - val_loss: 0.7676 - val_accuracy: 0.7484
# Epoch 27/30
# 86/86 [==============================] - 3s 32ms/step - loss: 0.3343 - accuracy: 0.8757 - val_loss: 0.8632 - val_accuracy: 0.7190
# Epoch 28/30
# 86/86 [==============================] - 3s 37ms/step - loss: 0.3444 - accuracy: 0.8634 - val_loss: 0.8356 - val_accuracy: 0.7277
# Epoch 29/30
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3229 - accuracy: 0.8823 - val_loss: 0.8866 - val_accuracy: 0.7179
# Epoch 30/30
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3222 - accuracy: 0.8848 - val_loss: 0.7913 - val_accuracy: 0.7386
