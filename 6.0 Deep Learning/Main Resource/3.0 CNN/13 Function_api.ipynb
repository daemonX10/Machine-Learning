# %% [markdown]
# <a href="https://colab.research.google.com/github/daemonX10/Data-Science/blob/main/Function_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model

# %%
from keras.layers import *

# %%
x = Input(shape = (3,3))

# %%
hidden1 = Dense(128,activation = 'relu')(x)
hidden2 = Dense(64,activation = 'relu')(hidden1)
output1 = Dense(1,activation = 'linear' )(hidden2)
output2 = Dense(1,activation = 'sigmoid' )(hidden2)

# %%
model = Model(inputs = x, outputs = [output1,output2])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 3, 3)]               0         []
#
#  dense (Dense)               (None, 3, 128)               512       ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 3, 64)                8256      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3, 1)                 65        ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 3, 1)                 65        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 8898 (34.76 KB)
# Trainable params: 8898 (34.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes = True)

# %% [markdown]
# ## Second one (Complex)

# %%
InputA = Input(shape = (32,))
InputB = Input(shape=(128))

# %%
x = Dense(8,activation = 'relu')(InputA)
x1 = Dense(4 ,activation = 'relu')(x)

# %%
y = Dense( 64,activation = 'relu')(InputB)
y1 = Dense(32 ,activation = 'relu')(y)
y2 = Dense(4,activation = 'relu')(y1)

# %%
combined = Concatenate()([x1,y2])

# %%
z = Dense(2,activation='relu')(combined)
z1 = Dense(1,activation ='linear' )(z)

# %%
model = Model(inputs = [InputA,InputB],outputs = z1)

# %%
plot_model(model)
