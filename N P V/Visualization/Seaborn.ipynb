# %% [markdown]
# Seaborn provides several options to customize the colors and styles of your plots:
#
# 1. **Color Palettes**: Seaborn allows you to customize the color palette of your plots. You can use predefined color palettes such as 'Dark2', 'Blues', etc., or define your own color palette. You can set the color palette using the `set_palette()` function or directly in the plotting function with the `palette` parameter.
#
#     ```python
#     sns.set_palette("Dark2")
#     sns.pairplot(iris, hue='species')
#     ```
#
#     Or
#
#     ```python
#     sns.pairplot(iris, hue='species', palette='Dark2')
#     ```
#
# 2. **Plot Style**: Seaborn provides five predefined themes to style your plots: 'darkgrid', 'whitegrid', 'dark', 'white', and 'ticks'. You can set the theme using the `set_style()` function.
#
#     ```python
#     sns.set_style("whitegrid")
#     sns.pairplot(iris, hue='species', palette='Dark2')
#     ```
#
# 3. **Context**: Seaborn provides four predefined contexts for your plots: 'paper', 'notebook', 'talk', and 'poster'. The context sets the scale of the plot and allows you to customize the plot for different settings. You can set the context using the `set_context()` function.
#
#     ```python
#     sns.set_context("paper")
#     sns.pairplot(iris, hue='species', palette='Dark2')
#     ```
#
# 4. **Color Maps**: For functions that visualize a two-dimensional grid of data, Seaborn also allows you to specify a color map. This is a way to map data values to a range of colors. You can specify the color map with the `cmap` parameter.
#
#     ```python
#     sns.heatmap(data, cmap='Blues')
#     ```
#
# 5. **Plot Scaling**: Seaborn also allows you to control the scale of your plot elements, which can be useful for tailoring your plot for a presentation or report.
#
#     ```python
#     sns.set(font_scale=1.5)
#     sns.pairplot(iris, hue='species', palette='Dark2')
#     ```
#
# These are just a few examples of the customization options that Seaborn provides. For more information, you can refer to the [official Seaborn documentation](https://seaborn.pydata.org/).

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris, hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = iris.sepal_length,y = iris.sepal_width , hue = iris.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = iris.sepal_length,y= iris.sepal_width , hue= iris.species, style= iris.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.displot(iris['sepal_length'])

# %%
sns.displot(iris['sepal_width'],
kde = False, bins = 10, color = 'red')
#  The `kde = False` parameter in the `sns.displot()` function is used to disable the kernel density estimation (KDE) plot. By setting `kde = False`, the function will only display the histogram of the data without the KDE plot.
# The `bins = 10` parameter in the `sns.displot()` function is used to specify the number of bins to be used in the histogram. In this case, it is set to 10, which means the data will be divided into 10 equal-width bins for the histogram.

# %%
sns.displot(iris['sepal_width'],
kde = True, bins = 10, color = 'red')

# %%
# `sns.displot(iris['sepal_width'])` is creating a histogram of the sepal width values from the iris dataset using the seaborn library.
sns.displot(iris['sepal_width'])

# %%
tip = sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x= tip.total_bill , y = tip.tip )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tip['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tip['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.regplot(x = tip.total_bill, y = tip.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = tip.total_bill, y = tip.tip, hue = tip.smoker)

# %%
sns.relplot(x = tip.total_bill, y = tip.tip, data = tip , hue='smoker',style='smoker', style_order=['No','Yes'])

# %%
sns.relplot(x = tip.total_bill, y = tip.tip, data = tip , hue='smoker',style='smoker', style_order=['No','Yes'], col = 'smoker')

# %%
sns.relplot(x = tip.total_bill, y = tip.tip, data = tip , hue='smoker',style='smoker', style_order=['No','Yes'], row = 'size')

# %%
sns.relplot(x = tip.total_bill , y = tip.tip , data = tip,style=  'size' )

# %%
sns.relplot(x = tip.total_bill , y = tip.tip , data = tip,style=  'size' , hue='time')

# %% [markdown]
# ## CatPlot

# %%
sns.catplot(x = 'day',y= 'tip', data = tip, kind = 'bar' , row='size')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tip)

# %%
sns.pairplot(tip)

# %%
sns.pairplot(iris)

# %%
sns.set_style("whitegrid")
sns.pairplot(iris, hue='species', palette='Dark2')

# %%
sns.set_context("talk")
sns.pairplot(iris, hue='species', palette='Dark2')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

iris.describe()
plt.figure(figsize=(10, 8))
sns.pairplot(iris, hue='species', palette='Dark2')

# %%
iris.describe()

sns.pairplot(iris, hue='species', palette='Dark2')

# %%
sns.set(font_scale=1.5)
sns.pairplot(iris, hue='species', palette='Dark2')

# %%
import seaborn as sns
sns.set_theme(style="white")

df = sns.load_dataset("penguins")

g = sns.JointGrid(data=df, x="body_mass_g", y="bill_depth_mm", space=0)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((2200, 6800), (10, 25)),
             thresh=0, levels=100, cmap="rocket")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >
