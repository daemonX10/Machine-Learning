# %%
# !pip install bokeh
# Out:
# Collecting bokeh
#   Downloading bokeh-3.3.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (1.26.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (2.1.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (10.2.0)
# Collecting PyYAML>=3.10 (from bokeh)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: tornado>=5.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from bokeh) (6.4)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Downloading bokeh-3.3.4-py3-none-any.whl (6.8 MB)
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.8 MB 5.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/6.8 MB 5.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/6.8 MB 4.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.8 MB 4.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.8 MB 5.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/6.8 MB 4.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.8 MB 5.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.8 MB 4.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.0/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------- -------------------------- 2.2/6.8 MB 4.9 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.8 MB 5.0 MB/s eta 0:00:01
#    --------------- ------------------------ 2.7/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/6.8 MB 4.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.8 MB 4.9 MB/s eta 0:00:01
#    -------------------- ------------------- 3.6/6.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.8/6.8 MB 4.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------------------- -------------- 4.3/6.8 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.8 MB 4.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.8 MB 5.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.4/6.8 MB 4.9 MB/s eta 0:00:01
#    --------------------------------- ------ 5.6/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.8/6.8 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/6.8 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.8 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 6.5/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.8/6.8 MB 4.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    -------------------------------------- - 133.1/138.7 kB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 138.7/138.7 kB 1.6 MB/s eta 0:00:00
# Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/56.3 kB ? eta -:--:--
#    ---------------------------------------- 56.3/56.3 kB 979.7 kB/s eta 0:00:00
# Installing collected packages: xyzservices, PyYAML, bokeh
# Successfully installed PyYAML-6.0.1 bokeh-3.3.4 xyzservices-2023.10.1

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cfb8aa8c-cb11-4845-9513-b1f28200ef09">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file , show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
p= figure(title='test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label= "petal_width" 
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="b9721dc5-6272-4e6a-8992-f32e46c0a2de" data-root-id="p1045" style="display: contents;"></div>

# %%
output_file('test.html')

p = figure(title = 'test flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="fe49978a-1d8c-4ddf-bedd-76573476a821" data-root-id="p1089" style="display: contents;"></div>

# %%
x = [3,4,7,8,12] 
y = [5,8,9,12,15]
output_file('line.html')
p = figure(title = 'line graph')
p.line(x,y)
show(p)
# Out:
#   <div id="e435ec68-4763-47a0-b8f1-9f4e1f784f1d" data-root-id="p1136" style="display: contents;"></div>

# %%
x = [3,4,7,8,12]
y = [5,8,9,12,15]
output_file('line.html')
p = figure(title = 'line graph')
p.scatter(x,y, size = 20, color = 'red',legend_label = 'circle')
show(p)
# Out:
#   <div id="f0e1c59a-1853-4c9f-bb8b-3900c7003518" data-root-id="p1225" style="display: contents;"></div>
